# %%
import pandas as pd

# %%
# Asumiendo que df_equipos.pkl está en la carpeta data, 
# y que tu notebook está en un directorio que tiene la carpeta data como subdirectorio
df_equipos = pd.read_pickle('df_equipos.pkl')

# Muestra las primeras filas del DataFrame para verificar que se ha cargado correctamente
df_equipos.head()
# Out:
#    id_equipo            nombre_equipo     nombre_comun      id_temporada  \
# 0        456            Villarreal CF       Villarreal  13/14_CopaReyESP
# 1        457             FC Barcelona     FC Barcelona  13/14_CopaReyESP
# 2        458           Real Madrid CF      Real Madrid  13/14_CopaReyESP
# 3        459               Sevilla FC       Sevilla FC  13/14_CopaReyESP
# 4        460  Club Atlético de Madrid  Atlético Madrid  13/14_CopaReyESP
#
#    id_pais  partidos_jugados  partidos_jugados_casa  partidos_jugados_fuera  \
# 0      724                 4                      2                       2
# 1      724                 9                      5                       4
# 2      724                 9                      4                       5
# 3      724                 2                      1                       1
# 4      724                 8                      4                       4
#
# ...

# %%
# Filtrar las filas donde id_equipo es 480
df_equipos_480 = df_equipos[df_equipos['id_equipo'] == 480]

# Mostrar las primeras filas del DataFrame filtrado para verificar
df_equipos_480
# Out:
#       id_equipo nombre_equipo nombre_comun      id_temporada  id_pais  \
# 24          480      Elche CF     Elche CF  13/14_CopaReyESP      724
# 107         480      Elche CF     Elche CF  14/15_CopaReyESP      724
# 190         480      Elche CF     Elche CF  15/16_CopaReyESP      724
# 273         480      Elche CF     Elche CF  16/17_CopaReyESP      724
# 356         480      Elche CF     Elche CF  17/18_CopaReyESP      724
# 439         480      Elche CF     Elche CF  18/19_CopaReyESP      724
# 538         480      Elche CF     Elche CF  19/20_CopaReyESP      724
# 643         480      Elche CF     Elche CF  20/21_CopaReyESP      724
# 788         480      Elche CF     Elche CF  21/22_CopaReyESP      724
# 914         480      Elche CF     Elche CF  22/23_CopaReyESP      724
# 1039        480      Elche CF     Elche CF  23/24_CopaReyESP      724
# 1182        480      Elche CF     Elche CF     13/14_LaLiga1      724
# ...
